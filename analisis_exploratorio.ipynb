# %% [markdown]
# ## Analisis exploratorio de las fuentes de datos disponibles:

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Fuente 1: Información de consumo dentro de la plataforma

# %%
fuente1 = pd.read_csv("../data/usuarios_segmentados.csv") #Fuente 1: Información de consumo dentro de la plataforma

# %%
len(fuente1) #Cantidad total de filas
# Out:
# 300

# %%
fuente1.info() #Información del dataset
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 19 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   id_cliente                       300 non-null    int64
#  1   horas_consumo_mensual            300 non-null    int64
#  2   gasto_mensual                    300 non-null    int64
#  3   cantidad_contenidos_vistos       300 non-null    int64
#  4   sesiones_semana                  300 non-null    int64
#  5   porcentaje_finalizacion          300 non-null    int64
#  6   tiempo_promedio_sesion_min       300 non-null    int64
#  7   cantidad_generos_consumidos      300 non-null    int64
#  8   porcentaje_uso_promociones       300 non-null    float64
#  9   antiguedad_cliente_meses         300 non-null    int64
#  10  edad                             300 non-null    float64
#  11  dispositivos_registrados         300 non-null    int64
# ...

# %% [markdown]
# ## Fuente 2: Información complementaria del usuario

# %%
fuente2 = pd.read_csv("../database/perfil_usuarios.csv") #Fuente 2: Información complementaria del usuario

# %%
fuente2.shape[0] #Cantidad total de filas
# Out:
# 300

# %%
fuente2.info() #Información del dataset
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 7 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   id_cliente                       300 non-null    int64
#  1   edad                             300 non-null    int64
#  2   dispositivos_registrados         300 non-null    int64
#  3   porcentaje_uso_app_movil         300 non-null    float64
#  4   cantidad_perfiles_creados        300 non-null    int64
#  5   interacciones_mensuales_soporte  300 non-null    int64
#  6   distancia_promedio_red_km        300 non-null    float64
# dtypes: float64(2), int64(5)
# memory usage: 16.5 KB
